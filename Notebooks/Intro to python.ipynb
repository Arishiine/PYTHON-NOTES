# %% [markdown]
# ## INTRODUCTION TO PYTHON - THE PROGRAMMING LANGUAGE

# %%
#python the programming language
'This is Python'
# Out:
# 'This is Python'

# %% [markdown]
# - This notebook will cover what python can do
# - Why python
